# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score

# %%
matches = pd.read_csv('matches.csv', index_col= 0)

# %%
matches.shape
# Out:
# (1680, 27)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  14:00  Premier League  Matchweek 1  Sun  Away      D  2.0  2.0
# 1  2023-08-19  17:30  Premier League  Matchweek 2  Sat  Home      W  2.0  0.0
# 2  2023-08-26  12:30  Premier League  Matchweek 3  Sat  Away      W  2.0  0.0
# 4  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Away      W  5.0  2.0
# 5  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 0       Brentford  ...  Match Report    NaN  18.0   6.0  19.6  0.0  0.0   0.0
# 1  Manchester Utd  ...  Match Report    NaN  17.0   6.0  13.8  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  17.0   6.0  16.6  1.0  0.0   0.0
# 4         Burnley  ...  Match Report    NaN  21.0  11.0  19.3  0.0  0.0   0.0
# 5   Sheffield Utd  ...  Match Report    NaN  28.0  10.0  16.4  0.0  0.0   0.0
#
#    season               team
# 0    2023  Tottenham Hotspur
# 1    2023  Tottenham Hotspur
# 2    2023  Tottenham Hotspur
# 4    2023  Tottenham Hotspur
# 5    2023  Tottenham Hotspur
#
# [5 rows x 27 columns]

# %%
matches['team'].value_counts()
# Out:
# Tottenham Hotspur           84
# Crystal Palace              84
# Everton                     84
# Brentford                   84
# Wolverhampton Wanderers     84
# Arsenal                     84
# Chelsea                     84
# Manchester United           84
# Newcastle United            84
# West Ham United             84
# Brighton and Hove Albion    84
# Aston Villa                 84
# Liverpool                   84
# Manchester City             84
# Southampton                 76
# Leeds United                76
# Leicester City              76
# Bournemouth                 46
# Nottingham Forest           46
# Burnley                     46
# Fulham                      46
# Watford                     38
# Norwich City                38
# Sheffield United             8
# Luton Town                   8
# Name: team, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 7     60
# Matchweek 8     60
# Matchweek 2     60
# Matchweek 33    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 29    40
# Matchweek 30    40
# Matchweek 31    40
# Matchweek 35    40
# Matchweek 34    40
# Matchweek 28    40
# Matchweek 24    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 32    40
# Matchweek 25    40
# Matchweek 21    40
# Matchweek 12    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 17    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 14    40
# Matchweek 13    40
# Matchweek 11    40
# Matchweek 10    40
# Matchweek 9     40
# Matchweek 38    40
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date']=pd.to_datetime(matches['date'])

# %%
# Create a predictor for the ML model (venue column as the model will only work with numerical values. Home advantage is a great predictor for possible win or loss)
matches['venue_code']= matches['venue'].astype('category').cat.codes

# %%
# Create a predictor for the ML model(Opponent column as the model will only work with numerical values)
matches['opp_code']= matches['opponent'].astype('category').cat.codes

# %%
# Create a predictor for the ML model(Hour column as the model will only work with numerical values. We are assuming that the time the match is been played affects performance)
matches['hour']= matches['time'].str.replace(":.+","",regex=True).astype('int')

# %%
# Create a predictor for the ML model()
matches['day_code']= matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  14:00  Premier League   Matchweek 1  Sun  Away      D  2.0
# 1  2023-08-19  17:30  Premier League   Matchweek 2  Sat  Home      W  2.0
# 2  2023-08-26  12:30  Premier League   Matchweek 3  Sat  Away      W  2.0
# 4  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Away      W  5.0
# 5  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...   fk   pk  pkatt  season               team  \
# 0   2.0       Brentford  ...  0.0  0.0    0.0    2023  Tottenham Hotspur
# 1   0.0  Manchester Utd  ...  0.0  0.0    0.0    2023  Tottenham Hotspur
# 2   0.0     Bournemouth  ...  1.0  0.0    0.0    2023  Tottenham Hotspur
# 4   2.0         Burnley  ...  0.0  0.0    0.0    2023  Tottenham Hotspur
# 5   1.0   Sheffield Utd  ...  0.0  0.0    0.0    2023  Tottenham Hotspur
# ..  ...             ...  ...  ...  ...    ...     ...                ...
# 38  2.0     Aston Villa  ...  0.0  0.0    0.0    2021       Norwich City
# 39  4.0        West Ham  ...  1.0  0.0    0.0    2021       Norwich City
# 40  3.0  Leicester City  ...  0.0  0.0    0.0    2021       Norwich City
# 41  1.0          Wolves  ...  0.0  0.0    0.0    2021       Norwich City
# 42  5.0       Tottenham  ...  0.0  0.0    0.0    2021       Norwich City
#
#    venue_code opp_code hour  day_code  target
# 0           0        3   14         6       0
# 1           1       15   17         5       1
# 2           0        2   12         5       1
# 4           0        5   15         5       1
# 5           1       19   15         5       1
# ..        ...      ...  ...       ...     ...
# 38          0        1   15         5       0
# 39          1       23   14         6       0
# 40          0       11   19         2       0
# 41          0       24   14         6       0
# 42          1       21   16         6       0
#
# [1680 rows x 32 columns]

# %%
#initialiaze the model
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
# Split training data
train = matches[matches['date'] < '2022-01-01']

# %%
# Split testing data
test = matches[matches['date'] > '2022-01-01']

# %%
# The predictors
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
# accuracy of the model
acc = accuracy_score(test['target'],preds)

# %%
print("Random Forest Classifier accuracy is : {:.2f}".format(acc))
# Out:
# Random Forest Classifier accuracy is : 0.59

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0    1
# actual
# 0           617  180
# 1           357  154

# %%
precision_score(test['target'],preds)
# Out:
# 0.4561933534743202

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group('Manchester United')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-14  20:00  Premier League   Matchweek 1  Mon  Home      W  1.0
# 1  2023-08-19  17:30  Premier League   Matchweek 2  Sat  Away      L  0.0
# 2  2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      W  3.0
# 3  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Away      L  1.0
# 4  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Home      L  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 44 2022-04-23  12:30  Premier League  Matchweek 34  Sat  Away      L  1.0
# 45 2022-04-28  19:45  Premier League  Matchweek 37  Thu  Home      D  1.0
# 46 2022-05-02  20:00  Premier League  Matchweek 35  Mon  Home      W  3.0
# 47 2022-05-07  17:30  Premier League  Matchweek 36  Sat  Away      L  0.0
# 48 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      ga         opponent  ...   fk   pk  pkatt  season               team  \
# 0   0.0           Wolves  ...  0.0  0.0    0.0    2023  Manchester United
# 1   2.0        Tottenham  ...  1.0  0.0    0.0    2023  Manchester United
# 2   2.0  Nott'ham Forest  ...  0.0  1.0    1.0    2023  Manchester United
# 3   3.0          Arsenal  ...  0.0  0.0    0.0    2023  Manchester United
# 4   3.0         Brighton  ...  1.0  0.0    0.0    2023  Manchester United
# ..  ...              ...  ...  ...  ...    ...     ...                ...
# 44  3.0          Arsenal  ...  0.0  0.0    1.0    2021  Manchester United
# 45  1.0          Chelsea  ...  0.0  0.0    0.0    2021  Manchester United
# 46  0.0        Brentford  ...  1.0  1.0    1.0    2021  Manchester United
# 47  4.0         Brighton  ...  1.0  0.0    0.0    2021  Manchester United
# 48  1.0   Crystal Palace  ...  1.0  0.0    0.0    2021  Manchester United
#
#    venue_code opp_code hour  day_code  target
# 0           1       24   20         0       1
# 1           0       21   17         5       0
# 2           1       18   15         5       1
# 3           0        0   16         6       0
# 4           1        4   15         5       0
# ..        ...      ...  ...       ...     ...
# 44          0        0   12         5       0
# 45          1        6   19         3       0
# 46          1        3   20         0       1
# 47          0        4   17         5       0
# 48          0        7   16         6       0
#
# [84 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  1.0
# 5  2021-09-19  14:00  Premier League  Matchweek 5  Sun  Away      W  2.0  1.0
# 7  2021-09-25  12:30  Premier League  Matchweek 6  Sat  Home      L  0.0  1.0
# 9  2021-10-02  12:30  Premier League  Matchweek 7  Sat  Home      D  1.0  1.0
# 10 2021-10-16  15:00  Premier League  Matchweek 8  Sat  Away      L  2.0  4.0
# ..        ...    ...             ...          ...  ...   ...    ...  ...  ...
# 3  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Away      L  1.0  3.0
# 4  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Home      L  1.0  3.0
# 6  2023-09-23  20:00  Premier League  Matchweek 6  Sat  Away      W  1.0  0.0
# 8  2023-09-30  15:00  Premier League  Matchweek 7  Sat  Home      L  0.0  1.0
# 10 2023-10-07  15:00  Premier League  Matchweek 8  Sat  Home      W  2.0  1.0
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 3    Newcastle Utd  ...         5       1    2.333333    0.666667  13.666667
# 5         West Ham  ...         6       1    2.000000    0.666667  15.333333
# 7      Aston Villa  ...         5       0    2.333333    0.666667  16.000000
# 9          Everton  ...         5       0    2.000000    1.000000  21.666667
# 10  Leicester City  ...         5       0    1.000000    1.000000  19.000000
# ..             ...  ...       ...     ...         ...         ...        ...
# 3          Arsenal  ...         6       0    1.333333    1.333333  18.000000
# 4         Brighton  ...         5       0    1.333333    2.333333  16.333333
# 6          Burnley  ...         5       1    1.666667    2.666667  13.666667
# 8   Crystal Palace  ...         5       0    1.000000    2.000000  11.666667
# 10       Brentford  ...         5       1    0.666667    1.333333  14.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3     4.666667    17.366667   0.666667    0.000000       0.000000
# 5     4.000000    18.133333   0.666667    0.000000       0.000000
# 7     6.333333    18.800000   0.333333    0.000000       0.000000
# 9     6.666667    19.100000   0.666667    0.000000       0.333333
# 10    6.666667    17.300000   0.666667    0.000000       0.333333
# ..         ...          ...        ...         ...            ...
# 3     5.333333    16.866667   0.333333    0.333333       0.333333
# 4     5.333333    17.466667   0.333333    0.333333       0.333333
# 6     4.666667    18.466667   0.333333    0.333333       0.333333
# 8     3.333333    16.700000   0.333333    0.000000       0.000000
# 10    3.666667    16.366667   0.333333    0.000000       0.000000
#
# [81 rows x 40 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling[matches_rolling['team'] == 'Manchester United']
# Out:
#                            date   time            comp        round  day  \
# team
# Manchester United 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat
#                   5  2021-09-19  14:00  Premier League  Matchweek 5  Sun
#                   7  2021-09-25  12:30  Premier League  Matchweek 6  Sat
#                   9  2021-10-02  12:30  Premier League  Matchweek 7  Sat
#                   10 2021-10-16  15:00  Premier League  Matchweek 8  Sat
# ...                         ...    ...             ...          ...  ...
#                   3  2023-09-03  16:30  Premier League  Matchweek 4  Sun
#                   4  2023-09-16  15:00  Premier League  Matchweek 5  Sat
#                   6  2023-09-23  20:00  Premier League  Matchweek 6  Sat
#                   8  2023-09-30  15:00  Premier League  Matchweek 7  Sat
#                   10 2023-10-07  15:00  Premier League  Matchweek 8  Sat
#
#                      venue result   gf   ga        opponent  ...  day_code  \
# team                                                         ...
# Manchester United 3   Home      W  4.0  1.0   Newcastle Utd  ...         5
#                   5   Away      W  2.0  1.0        West Ham  ...         6
#                   7   Home      L  0.0  1.0     Aston Villa  ...         5
#                   9   Home      D  1.0  1.0         Everton  ...         5
#                   10  Away      L  2.0  4.0  Leicester City  ...         5
# ...                    ...    ...  ...  ...             ...  ...       ...
#                   3   Away      L  1.0  3.0         Arsenal  ...         6
#                   4   Home      L  1.0  3.0        Brighton  ...         5
#                   6   Away      W  1.0  0.0         Burnley  ...         5
#                   8   Home      L  0.0  1.0  Crystal Palace  ...         5
#                   10  Home      W  2.0  1.0       Brentford  ...         5
#
#                       target  gf_rolling  ga_rolling sh_rolling sot_rolling  \
# team
# Manchester United 3        1    2.333333    0.666667  13.666667    4.666667
#                   5        1    2.000000    0.666667  15.333333    4.000000
#                   7        0    2.333333    0.666667  16.000000    6.333333
#                   9        0    2.000000    1.000000  21.666667    6.666667
#                   10       0    1.000000    1.000000  19.000000    6.666667
# ...                      ...         ...         ...        ...         ...
#                   3        0    1.333333    1.333333  18.000000    5.333333
#                   4        0    1.333333    2.333333  16.333333    5.333333
#                   6        1    1.666667    2.666667  13.666667    4.666667
#                   8        0    1.000000    2.000000  11.666667    3.333333
#                   10       1    0.666667    1.333333  14.666667    3.666667
#
#                      dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# team
# Manchester United 3     17.366667   0.666667    0.000000       0.000000
#                   5     18.133333   0.666667    0.000000       0.000000
#                   7     18.800000   0.333333    0.000000       0.000000
#                   9     19.100000   0.666667    0.000000       0.333333
#                   10    17.300000   0.666667    0.000000       0.333333
# ...                           ...        ...         ...            ...
#                   3     16.866667   0.333333    0.333333       0.333333
#                   4     17.466667   0.333333    0.333333       0.333333
#                   6     18.466667   0.333333    0.333333       0.333333
#                   8     16.700000   0.333333    0.000000       0.000000
#                   10    16.366667   0.333333    0.000000       0.000000
#
# [81 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Home      W  1.0  0.0
# 5  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Away      W  1.0  0.0
# 7  2021-09-26  16:30  Premier League  Matchweek 6  Sun  Home      W  3.0  1.0
# 8  2021-10-02  17:30  Premier League  Matchweek 7  Sat  Away      D  0.0  0.0
# 9  2021-10-18  20:00  Premier League  Matchweek 8  Mon  Home      D  2.0  2.0
# ..        ...    ...             ...          ...  ...   ...    ...  ...  ...
# 4  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Away      L  2.0  3.0
# 5  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Home      L  1.0  3.0
# 6  2023-09-23  15:00  Premier League  Matchweek 6  Sat  Away      D  1.0  1.0
# 8  2023-09-30  15:00  Premier League  Matchweek 7  Sat  Home      W  2.0  1.0
# 9  2023-10-08  14:00  Premier League  Matchweek 8  Sun  Home      D  1.0  1.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4      Norwich City  ...         5       1    0.000000    3.000000   9.666667
# 5           Burnley  ...         5       1    0.333333    2.333333  12.333333
# 7         Tottenham  ...         6       1    0.666667    1.666667  14.666667
# 8          Brighton  ...         5       0    1.666667    0.333333  18.333333
# 9    Crystal Palace  ...         0       0    1.333333    0.333333  11.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 4    Crystal Palace  ...         6       0    0.666667    1.666667  16.666667
# 5         Liverpool  ...         5       0    1.333333    2.333333  13.000000
# 6        Luton Town  ...         5       0    1.333333    2.000000  11.333333
# 8   Manchester City  ...         5       1    1.333333    2.333333   8.666667
# 9       Aston Villa  ...         6       0    1.333333    1.666667   5.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     2.333333    14.833333   0.333333         0.0            0.0
# 5     3.000000    14.133333   0.333333         0.0            0.0
# 7     3.000000    14.800000   0.666667         0.0            0.0
# 8     5.333333    18.433333   0.666667         0.0            0.0
# 9     4.000000    19.833333   0.666667         0.0            0.0
# ..         ...          ...        ...         ...            ...
# 4     4.333333    16.400000   0.333333         0.0            0.0
# 5     3.666667    16.700000   0.333333         0.0            0.0
# 6     2.666667    17.566667   0.333333         0.0            0.0
# 8     3.000000    13.966667   0.000000         0.0            0.0
# 9     2.000000    12.366667   0.000000         0.0            0.0
#
# [1605 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5070921985815603

# %%
combined
# Out:
#       actual  predicted
# 17         0          0
# 18         1          0
# 19         1          0
# 20         1          1
# 21         1          1
# ...      ...        ...
# 1600       0          0
# 1601       0          0
# 1602       0          0
# 1603       1          0
# 1604       0          0
#
# [1293 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 17         0          0 2022-01-23                  Arsenal          Burnley
# 18         1          0 2022-02-10                  Arsenal           Wolves
# 19         1          0 2022-02-19                  Arsenal        Brentford
# 20         1          1 2022-02-24                  Arsenal           Wolves
# 21         1          1 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 1600       0          0 2023-09-03  Wolverhampton Wanderers   Crystal Palace
# 1601       0          0 2023-09-16  Wolverhampton Wanderers        Liverpool
# 1602       0          0 2023-09-23  Wolverhampton Wanderers       Luton Town
# 1603       1          0 2023-09-30  Wolverhampton Wanderers  Manchester City
# 1604       0          0 2023-10-08  Wolverhampton Wanderers      Aston Villa
#
#      result
# 17        D
# 18        W
# 19        W
# 20        W
# 21        W
# ...     ...
# 1600      L
# 1601      L
# 1602      D
# 1603      W
# 1604      D
#
# [1293 rows x 6 columns]

# %%
# RESOLVING THE NAMES IN TEAM AND OPPPONENT
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date                   team_x  \
# 0            0            0 2022-01-23                  Arsenal
# 1            1            0 2022-02-10                  Arsenal
# 2            1            0 2022-02-19                  Arsenal
# 3            1            1 2022-02-24                  Arsenal
# 4            1            1 2022-03-06                  Arsenal
# ...        ...          ...        ...                      ...
# 1226         0            0 2023-09-03  Wolverhampton Wanderers
# 1227         0            0 2023-09-16  Wolverhampton Wanderers
# 1228         0            0 2023-09-23  Wolverhampton Wanderers
# 1229         1            0 2023-09-30  Wolverhampton Wanderers
# 1230         0            0 2023-10-08  Wolverhampton Wanderers
#
#            opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0             Burnley        D    Arsenal         0            0
# 1              Wolves        W    Arsenal         0            0
# 2           Brentford        W    Arsenal         0            0
# 3              Wolves        W    Arsenal         0            0
# 4             Watford        W    Arsenal         0            0
# ...               ...      ...        ...       ...          ...
# 1226   Crystal Palace        L     Wolves         1            1
# 1227        Liverpool        L     Wolves         1            1
# 1228       Luton Town        D     Wolves         0            0
# 1229  Manchester City        W     Wolves         0            0
# 1230      Aston Villa        D     Wolves         0            1
#
#                        team_y opponent_y result_y       new_team_y
# 0                     Burnley    Arsenal        D          Burnley
# 1     Wolverhampton Wanderers    Arsenal        L           Wolves
# 2                   Brentford    Arsenal        L        Brentford
# 3     Wolverhampton Wanderers    Arsenal        L           Wolves
# 4                     Watford    Arsenal        L          Watford
# ...                       ...        ...      ...              ...
# 1226           Crystal Palace     Wolves        W   Crystal Palace
# 1227                Liverpool     Wolves        W        Liverpool
# 1228               Luton Town     Wolves        D       Luton Town
# 1229          Manchester City     Wolves        L  Manchester City
# 1230              Aston Villa     Wolves        D      Aston Villa
#
# [1231 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    121
# 0    106
# Name: actual_x, dtype: int64

# %%
# Using GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Instantiate Gradient Boosting Regressor
gbc = GradientBoostingClassifier(n_estimators=300,
                                 learning_rate=0.05,
                                 random_state=1)

# %%
# Fit to training set
gbc.fit(train[predictors], train['target'])
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=300, random_state=1)

# %%
# Predict on test set
preds = gbc.predict(test[predictors])

# %%
# accuracy
acc = accuracy_score(test['target'],preds)

# %%
print("Gradient Boosting Classifier accuracy is : {:.2f}".format(acc))
# Out:
# Gradient Boosting Classifier accuracy is : 0.59

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0    1
# actual
# 0           617  180
# 1           360  151

# %%
precision_score(test['target'],preds)
# Out:
# 0.4561933534743202

# %%
# Using GBC with the new set of predictors
def make_predictions2(data, predictors):
    train = matches_rolling[matches_rolling["date"] < '2022-01-01']
    test = matches_rolling[matches_rolling["date"] > '2022-01-01']
    gbc.fit(train[predictors], train["target"])
    preds = gbc.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions2(matches_rolling, (predictors + new_cols))

# %%
print("Gradient Boosting Classifier accuracy is : {:.2f}".format(precision))
# Out:
# Gradient Boosting Classifier accuracy is : 0.50
